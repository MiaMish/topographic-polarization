# %%
from flow import SimilarityFlow

a = SimilarityFlow("aaa")
results = a.run_flow()
results.print_avg_results("aaa")
print("hi")
# Out:
# Starting to run type=SimilarityFlow
# title=aaa
# num_of_agents=30
# num_iterations=300
# scatter_every=30
# mio=0.4
# num_of_repetitions=20switch_agent_rate=None
# switch_agent_sigma=0.2
# radical_exposure_eta=Noneepsilon=0.1
# hi
